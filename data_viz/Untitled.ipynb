# %%
library(reshape2)

n = 10
set.seed(123)

mat = matrix(rnorm(n^2), ncol=n)
cmat = apply(mat, 2, cumsum)
cmat = t(cmat)
rownames(cmat) = paste("trial", seq(n), sep="")
colnames(cmat) = paste("time", seq(n), sep="")
dat = as.data.frame(cmat)
dat$trial = rownames(dat)
mdat = melt(dat, id.vars="trial")
mdat$time = as.numeric(gsub("time", "", mdat$variable))

# %%
print(mdat)
# Out:
#       trial variable         value time
# 1    trial1    time1 -0.5604756466    1
# 2    trial2    time1  1.2240817974    1
# 3    trial3    time1 -1.0678237060    1
# 4    trial4    time1  0.4264642215    1
# 5    trial5    time1 -0.6947069789    1
# 6    trial6    time1  0.2533185140    1
# 7    trial7    time1  0.3796394828    1
# 8    trial8    time1 -0.4910311661    1
# 9    trial9    time1  0.0057641859    1
# 10  trial10    time1  0.9935038560    1
# 11   trial1    time2 -0.7906531360    2
# 12   trial2    time2  1.5838956245    2
# 13   trial3    time2 -1.2857986206    2
# 14   trial4    time2  0.1313927385    2
# 15   trial5    time2 -0.9026242569    2
# 16   trial6    time2  0.2247717586    2
# 17   trial7    time2 -0.1226839703    2
# 18   trial8    time2 -2.8002000417    2
# 19   trial9    time2  0.3910445870    2
# 20  trial10    time2  1.5419008155    2
# 21   trial1    time3  0.7680551781    3
# 22   trial2    time3  1.9846670751    3
# 23   trial3    time3 -2.3118030690    3
# 24   trial4    time3  1.0265183995    3
# 25   trial5    time3 -2.1680206085    3
# 26   trial6    time3  0.1819013014    3
# 27   trial7    time3 -0.4558913540    3
# 28   trial8    time3 -1.7944615172    3
# 29   trial9    time3  0.0203845552    3
# 30  trial10    time3  1.7806325506    3
# 31   trial1    time4  0.8385635695    4
# 32   trial2    time4  2.0953497910    4
# 33   trial3    time4 -3.0406942982    4
# 34   trial4    time4  1.9046518871    4
# 35   trial5    time4  0.0009353568    4
# 36   trial6    time4  1.5505035854    4
# 37   trial7    time4 -1.4744667371    4
# 38   trial8    time4 -2.5036622798    4
# 39   trial9    time4  0.6647611038    4
# 40  trial10    time4  1.1527264745    4
# 41   trial1    time5  0.9678513047    5
# 42   trial2    time5  1.5395086563    5
# 43   trial3    time5 -3.6657335661    5
# 44   trial4    time5  2.7262329687    5
# 45   trial5    time5  1.2088973551    5
# 46   trial6    time5  1.3247325997    5
# 47   trial7    time5 -2.5462579636    5
# 48   trial8    time5 -3.1916708963    5
# 49   trial9    time5  0.4442745419    5
# 50  trial10    time5  2.5133789231    5
# 51   trial1    time6  2.6829162916    6
# 52   trial2    time6  3.3264217931    6
# 53   trial3    time6 -5.3524268768    6
# 54   trial4    time6  3.4148732228    6
# 55   trial5    time6  0.0857887719    6
# 56   trial6    time6  2.8412032041    6
# 57   trial7    time6 -2.2427293222    6
# 58   trial8    time6 -2.1660995266    6
# 59   trial9    time6  0.7760565058    6
# 60  trial10    time6  1.9131193359    6
# 61   trial1    time7  3.1438324976    7
# 62   trial2    time7  3.8242722713    7
# 63   trial3    time7 -4.5146398323    7
# 64   trial4    time7  3.9687908763    7
# 65   trial5    time7 -0.3170960634    7
# 66   trial6    time7  1.2924503999    7
# 67   trial7    time7 -1.7945195436    7
# 68   trial8    time7 -2.4508725336    7
# 69   trial9    time7  1.8728955190    7
# 70  trial10    time7  4.1004523289    7
# 71   trial1    time8  1.8787712630    8
# 72   trial2    time8  1.8576551147    8
# 73   trial3    time8 -4.3612667145    8
# 74   trial4    time8  3.9068791658    8
# 75   trial5    time8 -0.7837514170    8
# 76   trial6    time8  1.8770641495    8
# 77   trial7    time8 -1.7415153168    8
# 78   trial8    time8 -3.6715902459    8
# 79   trial9    time8  2.3080770098    8
# 80  trial10    time8  5.6330629551    8
# 81   trial1    time9  1.1919184111    9
# 82   trial2    time9  2.5590110162    9
# 83   trial3    time9 -5.4994036515    9
# 84   trial4    time9  3.6009165020    9
# 85   trial5    time9 -0.0037862987    9
# 86   trial6    time9  2.0009183934    9
# 87   trial7    time9 -0.8192478490    9
# 88   trial8    time9 -3.4902867661    9
# 89   trial9    time9  1.9821454243    9
# 90  trial10    time9  5.3973625960    9
# 91   trial1   time10  0.7462564410   10
# 92   trial2   time10  2.0862196085   10
# 93   trial3   time10 -4.2455887304   10
# 94   trial4   time10  3.2204455010   10
# 95   trial5   time10 -0.0871553651   10
# 96   trial6   time10  2.2168599621   10
# 97   trial7   time10  1.2308368367   10
# 98   trial8   time10 -3.6291781286   10
# 99   trial9   time10  3.1309530428   10
# 100 trial10   time10  4.3709416957   10
